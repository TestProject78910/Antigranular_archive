# %%
import antigranular as ag

# %%
import antigranular as ag
session = ag.login(<client_id>,<client_secret>, competition = "Sandbox Competition")
# Out:
# Dataset "Medical Treatment" loaded to the kernel as medical_treatment
# Key Name                       Value Type
# ---------------------------------------------
# train_x                        PrivateDataFrame
# train_y                        PrivateDataFrame
# test_x                         DataFrame
#
# Dataset "Cancer Dataset" loaded to the kernel as cancer_dataset
# Key Name                       Value Type
# ---------------------------------------------
# train_x                        PrivateDataFrame
# train_y                        PrivateDataFrame
# test_x                         DataFrame
#
# Dataset "Adult Population Dataset" loaded to the kernel as adult_population_dataset
# Key Name                       Value Type
# ---------------------------------------------
# train_x                        PrivateDataFrame
# train_y                        PrivateDataFrame
# test_x                         DataFrame
#
# Connected to Antigranular server session id: d22c14f5-6aee-48c9-8239-6a52528b359c, the session will time out if idle for 25 minutes
# Cell magic '%%ag' registered successfully, use `%%ag` in a notebook cell to execute your python code on Antigranular private python server
# 🚀 Everything's set up and ready to roll!

# %%
# %%ag
# medical_treatment['train_x'].info()
# Out:
# +----+------------------+-------------+---------------+---------+----------------------+
# |    | Column           | numerical   | categorical   | dtype   | bounds               |
# |----+------------------+-------------+---------------+---------+----------------------|
# |  0 | Participant ID   | True        | False         | int64   | (11111111, 11763738) |
# |  1 | Gender           | False       | True          | object  | None                 |
# |  2 | Age range        | False       | True          | object  | None                 |
# |  3 | Height (cm)      | True        | False         | int64   | (145, 210)           |
# |  4 | Eye Color        | False       | True          | object  | None                 |
# |  5 | Ethnicity        | False       | True          | object  | None                 |
# |  6 | Country of birth | False       | True          | object  | None                 |
# |  7 | Weight (kg)      | True        | False         | int64   | (35, 110)            |
# |  8 | SNP 0001         | True        | True          | bool    | None                 |
# |  9 | SNP 0002         | True        | True          | bool    | None                 |
# | 10 | SNP 0003         | True        | True          | bool    | None                 |
# | 11 | SNP 0004         | True        | True          | bool    | None                 |
# | 12 | SNP 0005         | True        | True          | bool    | None                 |
# | 13 | SNP 0006         | True        | True          | bool    | None                 |
# | 14 | SNP 0007         | True        | True          | bool    | None                 |
# | 15 | SNP 0008         | True        | True          | bool    | None                 |
# | 16 | SNP 0009         | True        | True          | bool    | None                 |
# | 17 | SNP 0010         | True        | True          | bool    | None                 |
# | 18 | SNP 0011         | True        | True          | bool    | None                 |
# | 19 | SNP 0012         | True        | True          | bool    | None                 |
# | 20 | SNP 0013         | True        | True          | bool    | None                 |
# +----+------------------+-------------+---------------+---------+----------------------+
